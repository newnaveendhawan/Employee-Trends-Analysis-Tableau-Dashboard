# %%
import pandas as pd
import sqlite3

# %%
df = pd.read_excel("Employee Trends Analysis - SQL.xlsx")  # Make sure filename is exact
df
# Out:
#       emp_no  gender marital_status age_group  age department  \
# 0      10001  Female         Single   35 - 44   41      Sales
# 1      10002    Male        Married   45 - 54   49        R&D
# 2      10003    Male         Single   35 - 44   37        R&D
# 3      10004  Female        Married   25 - 34   33        R&D
# 4      10005    Male        Married   25 - 34   27        R&D
# ...      ...     ...            ...       ...  ...        ...
# 1465   11466    Male        Married   25 - 34   34        R&D
# 1466   11467    Male         Single   25 - 34   29        R&D
# 1467   11468    Male         Single   35 - 44   35      Sales
# 1468   11469    Male         Single  Under 25   22        R&D
# 1469   11470    Male       Divorced  Under 25   23      Sales
#
#               education   education_field               job_role  \
# 0     Associates Degree     Life Sciences        Sales Executive
# 1           High School     Life Sciences     Research Scientist
# 2     Associates Degree             Other  Laboratory Technician
# 3       Master's Degree     Life Sciences     Research Scientist
# 4           High School           Medical  Laboratory Technician
# ...                 ...               ...                    ...
# 1465    Master's Degree  Technical Degree     Research Scientist
# 1466  Associates Degree     Life Sciences     Research Scientist
# 1467    Master's Degree             Other        Sales Executive
# 1468        High School     Life Sciences     Research Scientist
# 1469  Bachelor's Degree     Life Sciences   Sales Representative
#
#         business_travel  employee_count attrition    attrition_label  \
# 0         Travel_Rarely               1       Yes       Ex-Employees
# 1     Travel_Frequently               1        No  Current Employees
# 2         Travel_Rarely               1       Yes       Ex-Employees
# 3     Travel_Frequently               1        No  Current Employees
# 4         Travel_Rarely               1        No  Current Employees
# ...                 ...             ...       ...                ...
# 1465         Non-Travel               1       Yes       Ex-Employees
# 1466  Travel_Frequently               1       Yes       Ex-Employees
# 1467  Travel_Frequently               1       Yes       Ex-Employees
# 1468      Travel_Rarely               1       Yes       Ex-Employees
# 1469      Travel_Rarely               1       Yes       Ex-Employees
#
#       job_satisfaction  active_employee
# 0                    4                0
# 1                    2                1
# 2                    3                0
# 3                    3                1
# 4                    2                1
# ...                ...              ...
# 1465                 1                0
# 1466                 4                0
# 1467                 4                0
# 1468                 2                0
# 1469                 4                0
#
# [1470 rows x 15 columns]

# %%
conn = sqlite3.connect(":memory:")
df.to_sql("employee_data", conn, index=False, if_exists='replace')
# Out:
# 1470

# %%
pd.read_sql_query("SELECT * FROM employee_data LIMIT 5", conn)
# Out:
#    emp_no  gender marital_status age_group  age department          education  \
# 0   10001  Female         Single   35 - 44   41      Sales  Associates Degree
# 1   10002    Male        Married   45 - 54   49        R&D        High School
# 2   10003    Male         Single   35 - 44   37        R&D  Associates Degree
# 3   10004  Female        Married   25 - 34   33        R&D    Master's Degree
# 4   10005    Male        Married   25 - 34   27        R&D        High School
#
#   education_field               job_role    business_travel  employee_count  \
# 0   Life Sciences        Sales Executive      Travel_Rarely               1
# 1   Life Sciences     Research Scientist  Travel_Frequently               1
# 2           Other  Laboratory Technician      Travel_Rarely               1
# 3   Life Sciences     Research Scientist  Travel_Frequently               1
# 4         Medical  Laboratory Technician      Travel_Rarely               1
#
#   attrition    attrition_label  job_satisfaction  active_employee
# 0       Yes       Ex-Employees                 4                0
# 1        No  Current Employees                 2                1
# 2       Yes       Ex-Employees                 3                0
# 3        No  Current Employees                 3                1
# 4        No  Current Employees                 2                1

# %%
pd.read_sql_query("""
SELECT department, COUNT(*) AS employee_count
FROM employee_data
GROUP BY department
""", conn)
# Out:
#   department  employee_count
# 0         HR              63
# 1        R&D             961
# 2      Sales             446

# %%
pd.read_sql_query("""
SELECT department, AVG(age) AS average_age
FROM employee_data
GROUP BY department
""", conn)
# Out:
#   department  average_age
# 0         HR    37.809524
# 1        R&D    37.042664
# 2      Sales    36.542601

# %%
pd.read_sql_query("""
SELECT department, job_role, COUNT(*) AS role_count
FROM employee_data
GROUP BY department, job_role
ORDER BY department, role_count DESC
""", conn)
# Out:
#    department                   job_role  role_count
# 0          HR            Human Resources          52
# 1          HR                    Manager          11
# 2         R&D         Research Scientist         292
# 3         R&D      Laboratory Technician         259
# 4         R&D     Manufacturing Director         145
# 5         R&D  Healthcare Representative         131
# 6         R&D          Research Director          80
# 7         R&D                    Manager          54
# 8       Sales            Sales Executive         326
# 9       Sales       Sales Representative          83
# 10      Sales                    Manager          37

# %%
pd.read_sql_query("""
SELECT education, AVG(job_satisfaction) AS average_satisfaction
FROM employee_data
GROUP BY education
""", conn)
# Out:
#            education  average_satisfaction
# 0  Associates Degree              2.769504
# 1  Bachelor's Degree              2.652098
# 2    Doctoral Degree              2.666667
# 3        High School              2.800000
# 4    Master's Degree              2.786432

# %%
pd.read_sql_query("""
SELECT job_satisfaction, AVG(age) AS average_age
FROM employee_data
GROUP BY job_satisfaction
""", conn)
# Out:
#    job_satisfaction  average_age
# 0                 1    36.916955
# 1                 2    36.985714
# 2                 3    37.022624
# 3                 4    36.795207

# %%
pd.read_sql_query("""
SELECT department, AVG(job_satisfaction) AS average_satisfaction
FROM employee_data
GROUP BY department
ORDER BY average_satisfaction DESC
LIMIT 1
""", conn)
# Out:
#   department  average_satisfaction
# 0      Sales              2.751121

# %%
pd.read_sql_query("""
SELECT education, AVG(job_satisfaction) AS average_satisfaction
FROM employee_data
WHERE business_travel = 'Travel_Frequently'
GROUP BY education
ORDER BY average_satisfaction DESC
LIMIT 3
""", conn)
# Out:
#            education  average_satisfaction
# 0  Associates Degree              3.108696
# 1        High School              3.081081
# 2    Doctoral Degree              2.900000

# %%
pd.read_sql_query("""SELECT COUNT(*) AS total_employees FROM employee_data

""", conn)
# Out:
#    total_employees
# 0             1470

# %%
pd.read_sql_query("""SELECT COUNT(DISTINCT Department) AS total_departments FROM employee_data
""", conn)
# Out:
#    total_departments
# 0                  3

# %%
pd.read_sql_query("""SELECT COUNT(DISTINCT Job_Role) AS total_roles FROM employee_data
""", conn)
# Out:
#    total_roles
# 0            9

# %%
pd.read_sql_query("""SELECT Attrition, COUNT(*) AS total FROM employee_data GROUP BY Attrition
""", conn)
# Out:
#   attrition  total
# 0        No   1233
# 1       Yes    237

# %%
pd.read_sql_query("""SELECT Department,
       SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
FROM employee_data
GROUP BY Department
ORDER BY attrition_rate DESC
""", conn)
# Out:
#   department  attrition_rate
# 0      Sales       20.627803
# 1         HR       19.047619
# 2        R&D       13.839750

# %%
pd.read_sql_query("""SELECT Gender, COUNT(*) AS total FROM employee_data GROUP BY Gender
""", conn)
# Out:
#    gender  total
# 0  Female    588
# 1    Male    882

# %%
pd.read_sql_query("""SELECT Marital_Status, COUNT(*) AS total FROM employee_data GROUP BY Marital_Status
""", conn)
# Out:
#   marital_status  total
# 0       Divorced    327
# 1        Married    673
# 2         Single    470

# %%
pd.read_sql_query("""SELECT Age_Group, COUNT(*) AS total FROM employee_data GROUP BY Age_Group
""", conn)
# Out:
#   age_group  total
# 0   25 - 34    554
# 1   35 - 44    505
# 2   45 - 54    245
# 3   Over 55     69
# 4  Under 25     97

# %%
pd.read_sql_query("""SELECT Job_Role, COUNT(*) AS total FROM employee_data GROUP BY Job_Role ORDER BY total DESC
""", conn)
# Out:
#                     job_role  total
# 0            Sales Executive    326
# 1         Research Scientist    292
# 2      Laboratory Technician    259
# 3     Manufacturing Director    145
# 4  Healthcare Representative    131
# 5                    Manager    102
# 6       Sales Representative     83
# 7          Research Director     80
# 8            Human Resources     52

# %%
pd.read_sql_query("""SELECT Department, Job_Role, COUNT(*) AS role_count
FROM employee_data
GROUP BY Department, Job_Role
ORDER BY Department, role_count DESC
""", conn)
# Out:
#    department                   job_role  role_count
# 0          HR            Human Resources          52
# 1          HR                    Manager          11
# 2         R&D         Research Scientist         292
# 3         R&D      Laboratory Technician         259
# 4         R&D     Manufacturing Director         145
# 5         R&D  Healthcare Representative         131
# 6         R&D          Research Director          80
# 7         R&D                    Manager          54
# 8       Sales            Sales Executive         326
# 9       Sales       Sales Representative          83
# 10      Sales                    Manager          37

# %%
pd.read_sql_query("""SELECT Education, AVG(Job_Satisfaction) AS avg_satisfaction
FROM employee_data
GROUP BY Education
""", conn)
# Out:
#            education  avg_satisfaction
# 0  Associates Degree          2.769504
# 1  Bachelor's Degree          2.652098
# 2    Doctoral Degree          2.666667
# 3        High School          2.800000
# 4    Master's Degree          2.786432

# %%
pd.read_sql_query("""SELECT Education, AVG(Job_Satisfaction) AS avg_satisfaction
FROM employee_data
GROUP BY Education
""", conn)
# Out:
#            education  avg_satisfaction
# 0  Associates Degree          2.769504
# 1  Bachelor's Degree          2.652098
# 2    Doctoral Degree          2.666667
# 3        High School          2.800000
# 4    Master's Degree          2.786432

# %%
pd.read_sql_query("""SELECT Business_Travel,
       SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
FROM employee_data
GROUP BY Business_Travel
""", conn)
# Out:
#      business_travel  attrition_rate
# 0         Non-Travel        8.000000
# 1  Travel_Frequently       24.909747
# 2      Travel_Rarely       14.956855

# %%
pd.read_sql_query("""SELECT Education_field,
       SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
FROM employee_data
GROUP BY Education_field
ORDER BY attrition_rate DESC
""", conn)
# Out:
#     education_field  attrition_rate
# 0   Human Resources       25.925926
# 1  Technical Degree       24.242424
# 2         Marketing       22.012579
# 3     Life Sciences       14.686469
# 4           Medical       13.577586
# 5             Other       13.414634

# %%
pd.read_sql_query("""SELECT Job_Role,
       SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
FROM employee_data
GROUP BY Job_Role
ORDER BY attrition_rate DESC
LIMIT 5""", conn)
# Out:
#                 job_role  attrition_rate
# 0   Sales Representative       39.759036
# 1  Laboratory Technician       23.938224
# 2        Human Resources       23.076923
# 3        Sales Executive       17.484663
# 4     Research Scientist       16.095890

# %%
pd.read_sql_query("""SELECT Marital_Status, AVG(Job_Satisfaction) AS avg_satisfaction
FROM employee_data
GROUP BY Marital_Status""", conn)
# Out:
#   marital_status  avg_satisfaction
# 0       Divorced          2.697248
# 1        Married          2.716196
# 2         Single          2.768085

# %%
pd.read_sql_query("""SELECT Age_Group,
       SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
FROM employee_data
GROUP BY Age_Group
ORDER BY attrition_rate DESC""", conn)
# Out:
#   age_group  attrition_rate
# 0  Under 25       39.175258
# 1   25 - 34       20.216606
# 2   Over 55       15.942029
# 3   45 - 54       10.204082
# 4   35 - 44       10.099010

# %%
pd.read_sql_query("""
SELECT Department, Gender, COUNT(*) AS count
FROM employee_data
GROUP BY Department, Gender
ORDER BY Department
""", conn)
# Out:
#   department  gender  count
# 0         HR  Female     20
# 1         HR    Male     43
# 2        R&D  Female    379
# 3        R&D    Male    582
# 4      Sales  Female    189
# 5      Sales    Male    257

# %%
pd.read_sql_query("""
SELECT Gender,
       SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
FROM employee_data
GROUP BY Gender
""", conn)
# Out:
#    gender  attrition_rate
# 0  Female       14.795918
# 1    Male       17.006803

# %%
pd.read_sql_query("""
SELECT Marital_Status,
       SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
FROM employee_data
GROUP BY Marital_Status
""", conn)
# Out:
#   marital_status  attrition_rate
# 0       Divorced       10.091743
# 1        Married       12.481426
# 2         Single       25.531915

# %%
pd.read_sql_query("""
SELECT Job_Satisfaction,
       COUNT(*) AS total_employees,
       SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) AS attritions,
       SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
FROM employee_data
GROUP BY Job_Satisfaction
ORDER BY Job_Satisfaction
""", conn)
# Out:
#    job_satisfaction  total_employees  attritions  attrition_rate
# 0                 1              289          66       22.837370
# 1                 2              280          46       16.428571
# 2                 3              442          73       16.515837
# 3                 4              459          52       11.328976

# %%
pd.read_sql_query("""
SELECT Business_Travel, AVG(Job_Satisfaction) AS avg_satisfaction
FROM employee_data
GROUP BY Business_Travel
ORDER BY avg_satisfaction DESC
""", conn)
# Out:
#      business_travel  avg_satisfaction
# 0         Non-Travel          2.793333
# 1  Travel_Frequently          2.790614
# 2      Travel_Rarely          2.702780

# %%
pd.read_sql_query("""
SELECT Department, COUNT(*) AS active_count
FROM employee_data
WHERE Active_Employee = 1
GROUP BY Department
ORDER BY active_count DESC
LIMIT 3
""", conn)
# Out:
#   department  active_count
# 0        R&D           828
# 1      Sales           354
# 2         HR            51

# %%
pd.read_sql_query("""
SELECT Job_Role, AVG(Age) AS avg_age
FROM employee_data
GROUP BY Job_Role
ORDER BY avg_age DESC
""", conn)
# Out:
#                     job_role    avg_age
# 0                    Manager  46.764706
# 1          Research Director  44.000000
# 2  Healthcare Representative  39.809160
# 3     Manufacturing Director  38.296552
# 4            Sales Executive  36.889571
# 5            Human Resources  35.500000
# 6         Research Scientist  34.236301
# 7      Laboratory Technician  34.096525
# 8       Sales Representative  30.361446

# %%
pd.read_sql_query("""
SELECT Education_field, AVG(Job_Satisfaction) AS avg_satisfaction
FROM employee_data
GROUP BY Education_field
ORDER BY avg_satisfaction DESC
""", conn)
# Out:
#     education_field  avg_satisfaction
# 0     Life Sciences          2.797030
# 1             Other          2.743902
# 2           Medical          2.691810
# 3  Technical Degree          2.659091
# 4         Marketing          2.654088
# 5   Human Resources          2.555556

# %%
pd.read_sql_query("""
SELECT Marital_Status, Business_Travel,
       SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
FROM employee_data
GROUP BY Marital_Status, Business_Travel
ORDER BY attrition_rate DESC
""", conn)
# Out:
#   marital_status    business_travel  attrition_rate
# 0         Single  Travel_Frequently       38.541667
# 1         Single      Travel_Rarely       22.935780
# 2       Divorced  Travel_Frequently       20.634921
# 3         Single         Non-Travel       17.021277
# 4        Married  Travel_Frequently       16.101695
# 5        Married      Travel_Rarely       12.500000
# 6       Divorced      Travel_Rarely        8.636364
# 7        Married         Non-Travel        5.084746
# 8       Divorced         Non-Travel        2.272727

# %%
pd.read_sql_query("""
SELECT Emp_No, Department, Job_Role, Age, Job_Satisfaction, Business_Travel
FROM employee_data
WHERE Job_Satisfaction <= 2 AND Business_Travel = 'Travel_Frequently' AND Attrition = 'No'
""", conn)
# Out:
#     emp_no department                job_role  age  job_satisfaction  \
# 0    10002        R&D      Research Scientist   49                 2
# 1    10040      Sales         Sales Executive   33                 1
# 2    10057      Sales         Sales Executive   35                 1
# 3    10067        R&D  Manufacturing Director   36                 2
# 4    10069        R&D      Research Scientist   35                 1
# ..     ...        ...                     ...  ...               ...
# 67   11267        R&D      Research Scientist   38                 2
# 68   11302         HR         Human Resources   38                 2
# 69   11305        R&D   Laboratory Technician   36                 1
# 70   11343        R&D   Laboratory Technician   38                 2
# 71   11366        R&D      Research Scientist   31                 1
#
#       business_travel
# 0   Travel_Frequently
# 1   Travel_Frequently
# 2   Travel_Frequently
# 3   Travel_Frequently
# 4   Travel_Frequently
# ..                ...
# 67  Travel_Frequently
# 68  Travel_Frequently
# 69  Travel_Frequently
# 70  Travel_Frequently
# 71  Travel_Frequently
#
# [72 rows x 6 columns]

# %%
pd.read_sql_query("""
SELECT Education,
       SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
FROM employee_data
GROUP BY Education
ORDER BY attrition_rate DESC
""", conn)
# Out:
#            education  attrition_rate
# 0        High School       18.235294
# 1  Bachelor's Degree       17.307692
# 2  Associates Degree       15.602837
# 3    Master's Degree       14.572864
# 4    Doctoral Degree       10.416667

# %%
pd.read_sql_query("""
SELECT Department, Education, AVG(Job_Satisfaction) AS avg_satisfaction
FROM employee_data
GROUP BY Department, Education
ORDER BY Department, avg_satisfaction DESC
""", conn)
# Out:
#    department          education  avg_satisfaction
# 0          HR        High School          3.000000
# 1          HR    Master's Degree          2.733333
# 2          HR  Associates Degree          2.692308
# 3          HR  Bachelor's Degree          2.481481
# 4          HR    Doctoral Degree          2.000000
# 5         R&D        High School          2.843478
# 6         R&D    Doctoral Degree          2.800000
# 7         R&D    Master's Degree          2.772549
# 8         R&D  Associates Degree          2.725275
# 9         R&D  Bachelor's Degree          2.654354
# 10      Sales  Associates Degree          2.873563
# 11      Sales    Master's Degree          2.820312
# 12      Sales        High School          2.680000
# 13      Sales  Bachelor's Degree          2.674699
# 14      Sales    Doctoral Degree          2.533333

# %%
# 📦 Install required packages (if not already installed)
# !pip install openpyxl plotly

import pandas as pd
import sqlite3
import plotly.express as px

# ✅ Step 1: Load Excel and Prepare SQLite
excel_path = "/content/Employee Trends Analysis - SQL.xlsx"
df = pd.read_excel(excel_path)
df.columns = df.columns.str.strip().str.replace(" ", "_")

conn = sqlite3.connect(":memory:")
df.to_sql("employee_data", conn, index=False, if_exists='replace')

# ✅ Step 2: Define Queries
queries = {
    "Attrition by Department": """
        SELECT Department,
               SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
        FROM employee_data
        GROUP BY Department
        ORDER BY attrition_rate DESC
    """,

    "Satisfaction by Education Field": """
        SELECT Education_field, AVG(Job_Satisfaction) AS avg_satisfaction
        FROM employee_data
        GROUP BY Education_field
        ORDER BY avg_satisfaction DESC
    """,

    "Gender Distribution by Department": """
        SELECT Department, Gender, COUNT(*) AS count
        FROM employee_data
        GROUP BY Department, Gender
    """,

    "Attrition Rate by Marital Status": """
        SELECT Marital_Status,
               SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
        FROM employee_data
        GROUP BY Marital_Status
    """,

    "Attrition Rate by Job Satisfaction": """
        SELECT Job_Satisfaction,
               COUNT(*) AS total_employees,
               SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) AS attritions,
               SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
        FROM employee_data
        GROUP BY Job_Satisfaction
        ORDER BY Job_Satisfaction
    """,

    "Job Satisfaction by Business Travel": """
        SELECT Business_Travel, AVG(Job_Satisfaction) AS avg_satisfaction
        FROM employee_data
        GROUP BY Business_Travel
        ORDER BY avg_satisfaction DESC
    """,

    "Average Age by Job Role": """
        SELECT Job_Role, AVG(Age) AS avg_age
        FROM employee_data
        GROUP BY Job_Role
        ORDER BY avg_age DESC
    """,

    "Department & Education-wise Satisfaction": """
        SELECT Department, Education, AVG(Job_Satisfaction) AS avg_satisfaction
        FROM employee_data
        GROUP BY Department, Education
        ORDER BY Department, avg_satisfaction DESC
    """,

    "Attrition by Gender": """
        SELECT Gender,
               SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
        FROM employee_data
        GROUP BY Gender
    """,
}

# ✅ Step 3: Execute Queries and Plot
for title, sql in queries.items():
    df_result = pd.read_sql_query(sql, conn)
    print(f"\n📊 {title}:")
    display(df_result)

    # Auto-select chart type
    if "attrition_rate" in df_result.columns and "Department" in df_result.columns:
        fig = px.bar(df_result, x="Department", y="attrition_rate", title=title)
        fig.show()
    elif "avg_satisfaction" in df_result.columns and "Education_field" in df_result.columns:
        fig = px.bar(df_result, x="Education_field", y="avg_satisfaction", title=title)
        fig.show()
    elif "Gender" in df_result.columns and "count" in df_result.columns:
        fig = px.bar(df_result, x="Department", y="count", color="Gender", barmode="group", title=title)
        fig.show()
    elif "Job_Role" in df_result.columns:
        fig = px.bar(df_result, x="Job_Role", y="avg_age", title=title)
        fig.show()
    elif "Business_Travel" in df_result.columns:
        fig = px.bar(df_result, x="Business_Travel", y="avg_satisfaction", title=title)
        fig.show()
    elif "Job_Satisfaction" in df_result.columns and "attrition_rate" in df_result.columns:
        fig = px.bar(df_result, x="Job_Satisfaction", y="attrition_rate", title=title)
        fig.show()

# ✅ Done!
# Out:
# 📊 Attrition by Department:
#   department  attrition_rate
# 0      Sales       20.627803
# 1         HR       19.047619
# 2        R&D       13.839750
# 📊 Satisfaction by Education Field:
#     education_field  avg_satisfaction
# 0     Life Sciences          2.797030
# 1             Other          2.743902
# 2           Medical          2.691810
# 3  Technical Degree          2.659091
# 4         Marketing          2.654088
# 5   Human Resources          2.555556
# 📊 Gender Distribution by Department:
#   department  gender  count
# 0         HR  Female     20
# 1         HR    Male     43
# 2        R&D  Female    379
# 3        R&D    Male    582
# 4      Sales  Female    189
# 5      Sales    Male    257
# 📊 Attrition Rate by Marital Status:
#   marital_status  attrition_rate
# 0       Divorced       10.091743
# 1        Married       12.481426
# 2         Single       25.531915
# 📊 Attrition Rate by Job Satisfaction:
#    job_satisfaction  total_employees  attritions  attrition_rate
# 0                 1              289          66       22.837370
# 1                 2              280          46       16.428571
# 2                 3              442          73       16.515837
# 3                 4              459          52       11.328976
# 📊 Job Satisfaction by Business Travel:
#      business_travel  avg_satisfaction
# 0         Non-Travel          2.793333
# 1  Travel_Frequently          2.790614
# 2      Travel_Rarely          2.702780
# 📊 Average Age by Job Role:
#                     job_role    avg_age
# 0                    Manager  46.764706
# 1          Research Director  44.000000
# 2  Healthcare Representative  39.809160
# 3     Manufacturing Director  38.296552
# 4            Sales Executive  36.889571
# 5            Human Resources  35.500000
# 6         Research Scientist  34.236301
# 7      Laboratory Technician  34.096525
# 8       Sales Representative  30.361446
# 📊 Department & Education-wise Satisfaction:
#    department          education  avg_satisfaction
# 0          HR        High School          3.000000
# 1          HR    Master's Degree          2.733333
# 2          HR  Associates Degree          2.692308
# 3          HR  Bachelor's Degree          2.481481
# 4          HR    Doctoral Degree          2.000000
# 5         R&D        High School          2.843478
# 6         R&D    Doctoral Degree          2.800000
# 7         R&D    Master's Degree          2.772549
# 8         R&D  Associates Degree          2.725275
# 9         R&D  Bachelor's Degree          2.654354
# 10      Sales  Associates Degree          2.873563
# 11      Sales    Master's Degree          2.820312
# 12      Sales        High School          2.680000
# 13      Sales  Bachelor's Degree          2.674699
# 14      Sales    Doctoral Degree          2.533333
# 📊 Attrition by Gender:
#    gender  attrition_rate
# 0  Female       14.795918
# 1    Male       17.006803

# %%
# 📦 Install required packages (if not already installed)
# !pip install openpyxl plotly

import pandas as pd
import sqlite3
import plotly.express as px

# ✅ Step 1: Load Excel and Prepare SQLite
excel_path = "/content/Employee Trends Analysis - SQL.xlsx"
df = pd.read_excel(excel_path)
df.columns = df.columns.str.strip().str.replace(" ", "_")

conn = sqlite3.connect(":memory:")
df.to_sql("employee_data", conn, index=False, if_exists='replace')

# ✅ Step 2: Define Queries
queries = {
    "1. Attrition by Department": """
        SELECT Department,
               SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
        FROM employee_data
        GROUP BY Department
        ORDER BY attrition_rate DESC
    """,

    "2. Satisfaction by Education Field": """
        SELECT Education_field, AVG(Job_Satisfaction) AS avg_satisfaction
        FROM employee_data
        GROUP BY Education_field
        ORDER BY avg_satisfaction DESC
    """,

    "3. Gender Distribution by Department": """
        SELECT Department, Gender, COUNT(*) AS count
        FROM employee_data
        GROUP BY Department, Gender
    """,

    "4. Attrition Rate by Marital Status": """
        SELECT Marital_Status,
               SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
        FROM employee_data
        GROUP BY Marital_Status
    """,

    "5. Attrition Rate by Job Satisfaction": """
        SELECT Job_Satisfaction,
               COUNT(*) AS total_employees,
               SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) AS attritions,
               SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
        FROM employee_data
        GROUP BY Job_Satisfaction
        ORDER BY Job_Satisfaction
    """,

    "6. Job Satisfaction by Business Travel": """
        SELECT Business_Travel, AVG(Job_Satisfaction) AS avg_satisfaction
        FROM employee_data
        GROUP BY Business_Travel
        ORDER BY avg_satisfaction DESC
    """,

    "7. Average Age by Job Role": """
        SELECT Job_Role, AVG(Age) AS avg_age
        FROM employee_data
        GROUP BY Job_Role
        ORDER BY avg_age DESC
    """,

    "8. Department & Education-wise Satisfaction": """
        SELECT Department, Education, AVG(Job_Satisfaction) AS avg_satisfaction
        FROM employee_data
        GROUP BY Department, Education
        ORDER BY Department, avg_satisfaction DESC
    """,

    "9. Attrition by Gender": """
        SELECT Gender,
               SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
        FROM employee_data
        GROUP BY Gender
    """,

    "10. Attrition Rate by Education": """
        SELECT Education,
               SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
        FROM employee_data
        GROUP BY Education
        ORDER BY attrition_rate DESC
    """,

    "11. Active Employees by Department": """
        SELECT Department, COUNT(*) AS active_count
        FROM employee_data
        WHERE Active_Employee = 1
        GROUP BY Department
        ORDER BY active_count DESC
        LIMIT 3
    """,

    "12. Satisfaction by Marital Status": """
        SELECT Marital_Status, AVG(Job_Satisfaction) AS avg_satisfaction
        FROM employee_data
        GROUP BY Marital_Status
        ORDER BY avg_satisfaction DESC
    """,

    "13. High Risk Employees (Low Satisfaction, High Travel)": """
        SELECT Emp_No, Department, Job_Role, Age, Job_Satisfaction, Business_Travel
        FROM employee_data
        WHERE Job_Satisfaction <= 2 AND Business_Travel = 'Travel_Frequently' AND Attrition = 'No'
    """,

    "14. Top Job Roles with High Attrition": """
        SELECT Job_Role, COUNT(*) AS total,
               SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) AS left,
               SUM(CASE WHEN Attrition = 'Yes' THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS attrition_rate
        FROM employee_data
        GROUP BY Job_Role
        ORDER BY attrition_rate DESC
        LIMIT 5
    """,

    "15. Average Age by Department": """
        SELECT Department, AVG(Age) AS avg_age
        FROM employee_data
        GROUP BY Department
        ORDER BY avg_age DESC
    """,

    "16. Employees Count by Education Field": """
        SELECT Education_field, COUNT(*) AS total
        FROM employee_data
        GROUP BY Education_field
        ORDER BY total DESC
    """,

    "17. Average Satisfaction by Job Role": """
        SELECT Job_Role, AVG(Job_Satisfaction) AS avg_satisfaction
        FROM employee_data
        GROUP BY Job_Role
        ORDER BY avg_satisfaction DESC
    """,

    "18. Business Travel by Department": """
        SELECT Department, Business_Travel, COUNT(*) AS count
        FROM employee_data
        GROUP BY Department, Business_Travel
        ORDER BY Department
    """,

    "19. Married Employees by Department": """
        SELECT Department, COUNT(*) AS married_count
        FROM employee_data
        WHERE Marital_Status = 'Married'
        GROUP BY Department
        ORDER BY married_count DESC
    """,

    "20. Education vs Job Role Satisfaction": """
        SELECT Education, Job_Role, AVG(Job_Satisfaction) AS avg_satisfaction
        FROM employee_data
        GROUP BY Education, Job_Role
        ORDER BY avg_satisfaction DESC
        LIMIT 10
    """,

    "21. Most Common Job Roles in Each Department": """
        SELECT Department, Job_Role, COUNT(*) AS role_count
        FROM employee_data
        GROUP BY Department, Job_Role
        ORDER BY Department, role_count DESC
    """,

    "22. Satisfaction by Education and Travel": """
        SELECT Education, Business_Travel, AVG(Job_Satisfaction) AS avg_satisfaction
        FROM employee_data
        GROUP BY Education, Business_Travel
        ORDER BY avg_satisfaction DESC
    """
}

# ✅ Step 3: Execute Queries and Plot
for title, sql in queries.items():
    df_result = pd.read_sql_query(sql, conn)
    print(f"\n📊 {title}:")
    display(df_result)

    # Auto-select chart type
    if "attrition_rate" in df_result.columns and "Department" in df_result.columns:
        fig = px.bar(df_result, x="Department", y="attrition_rate", title=title)
        fig.show()
    elif "avg_satisfaction" in df_result.columns and "Education_field" in df_result.columns:
        fig = px.bar(df_result, x="Education_field", y="avg_satisfaction", title=title)
        fig.show()
    elif "Gender" in df_result.columns and "count" in df_result.columns:
        fig = px.bar(df_result, x="Department", y="count", color="Gender", barmode="group", title=title)
        fig.show()
    elif "Job_Role" in df_result.columns and "avg_age" in df_result.columns:
        fig = px.bar(df_result, x="Job_Role", y="avg_age", title=title)
        fig.show()
    elif "Business_Travel" in df_result.columns and "avg_satisfaction" in df_result.columns:
        fig = px.bar(df_result, x="Business_Travel", y="avg_satisfaction", title=title)
        fig.show()
    elif "Job_Satisfaction" in df_result.columns and "attrition_rate" in df_result.columns:
        fig = px.bar(df_result, x="Job_Satisfaction", y="attrition_rate", title=title)
        fig.show()

# ✅ Done!
# Out:
# 📊 1. Attrition by Department:
#   department  attrition_rate
# 0      Sales       20.627803
# 1         HR       19.047619
# 2        R&D       13.839750
# 📊 2. Satisfaction by Education Field:
#     education_field  avg_satisfaction
# 0     Life Sciences          2.797030
# 1             Other          2.743902
# 2           Medical          2.691810
# 3  Technical Degree          2.659091
# 4         Marketing          2.654088
# 5   Human Resources          2.555556
# 📊 3. Gender Distribution by Department:
#   department  gender  count
# 0         HR  Female     20
# 1         HR    Male     43
# 2        R&D  Female    379
# 3        R&D    Male    582
# 4      Sales  Female    189
# 5      Sales    Male    257
# 📊 4. Attrition Rate by Marital Status:
#   marital_status  attrition_rate
# 0       Divorced       10.091743
# 1        Married       12.481426
# 2         Single       25.531915
# 📊 5. Attrition Rate by Job Satisfaction:
#    job_satisfaction  total_employees  attritions  attrition_rate
# 0                 1              289          66       22.837370
# 1                 2              280          46       16.428571
# 2                 3              442          73       16.515837
# 3                 4              459          52       11.328976
# 📊 6. Job Satisfaction by Business Travel:
#      business_travel  avg_satisfaction
# 0         Non-Travel          2.793333
# 1  Travel_Frequently          2.790614
# 2      Travel_Rarely          2.702780
# 📊 7. Average Age by Job Role:
#                     job_role    avg_age
# 0                    Manager  46.764706
# 1          Research Director  44.000000
# 2  Healthcare Representative  39.809160
# 3     Manufacturing Director  38.296552
# 4            Sales Executive  36.889571
# 5            Human Resources  35.500000
# 6         Research Scientist  34.236301
# 7      Laboratory Technician  34.096525
# 8       Sales Representative  30.361446
# 📊 8. Department & Education-wise Satisfaction:
#    department          education  avg_satisfaction
# 0          HR        High School          3.000000
# 1          HR    Master's Degree          2.733333
# 2          HR  Associates Degree          2.692308
# 3          HR  Bachelor's Degree          2.481481
# 4          HR    Doctoral Degree          2.000000
# 5         R&D        High School          2.843478
# 6         R&D    Doctoral Degree          2.800000
# 7         R&D    Master's Degree          2.772549
# 8         R&D  Associates Degree          2.725275
# 9         R&D  Bachelor's Degree          2.654354
# 10      Sales  Associates Degree          2.873563
# 11      Sales    Master's Degree          2.820312
# 12      Sales        High School          2.680000
# 13      Sales  Bachelor's Degree          2.674699
# 14      Sales    Doctoral Degree          2.533333
# 📊 9. Attrition by Gender:
#    gender  attrition_rate
# 0  Female       14.795918
# 1    Male       17.006803
# 📊 10. Attrition Rate by Education:
#            education  attrition_rate
# 0        High School       18.235294
# 1  Bachelor's Degree       17.307692
# 2  Associates Degree       15.602837
# 3    Master's Degree       14.572864
# 4    Doctoral Degree       10.416667
# 📊 11. Active Employees by Department:
#   department  active_count
# 0        R&D           828
# 1      Sales           354
# 2         HR            51
# 📊 12. Satisfaction by Marital Status:
#   marital_status  avg_satisfaction
# 0         Single          2.768085
# 1        Married          2.716196
# 2       Divorced          2.697248
# 📊 13. High Risk Employees (Low Satisfaction, High Travel):
#     emp_no department                job_role  age  job_satisfaction  \
# 0    10002        R&D      Research Scientist   49                 2
# 1    10040      Sales         Sales Executive   33                 1
# 2    10057      Sales         Sales Executive   35                 1
# 3    10067        R&D  Manufacturing Director   36                 2
# 4    10069        R&D      Research Scientist   35                 1
# ..     ...        ...                     ...  ...               ...
# 67   11267        R&D      Research Scientist   38                 2
# 68   11302         HR         Human Resources   38                 2
# 69   11305        R&D   Laboratory Technician   36                 1
# 70   11343        R&D   Laboratory Technician   38                 2
# 71   11366        R&D      Research Scientist   31                 1
#
#       business_travel
# 0   Travel_Frequently
# 1   Travel_Frequently
# 2   Travel_Frequently
# 3   Travel_Frequently
# 4   Travel_Frequently
# ..                ...
# 67  Travel_Frequently
# 68  Travel_Frequently
# 69  Travel_Frequently
# 70  Travel_Frequently
# 71  Travel_Frequently
#
# [72 rows x 6 columns]
# 📊 14. Top Job Roles with High Attrition:
#                 job_role  total  left  attrition_rate
# 0   Sales Representative     83    33       39.759036
# 1  Laboratory Technician    259    62       23.938224
# 2        Human Resources     52    12       23.076923
# 3        Sales Executive    326    57       17.484663
# 4     Research Scientist    292    47       16.095890
# 📊 15. Average Age by Department:
#   department    avg_age
# 0         HR  37.809524
# 1        R&D  37.042664
# 2      Sales  36.542601
# 📊 16. Employees Count by Education Field:
#     education_field  total
# 0     Life Sciences    606
# 1           Medical    464
# 2         Marketing    159
# 3  Technical Degree    132
# 4             Other     82
# 5   Human Resources     27
# 📊 17. Average Satisfaction by Job Role:
#                     job_role  avg_satisfaction
# 0  Healthcare Representative          2.786260
# 1         Research Scientist          2.773973
# 2            Sales Executive          2.754601
# 3       Sales Representative          2.734940
# 4                    Manager          2.705882
# 5          Research Director          2.700000
# 6      Laboratory Technician          2.691120
# 7     Manufacturing Director          2.682759
# 8            Human Resources          2.557692
# 📊 18. Business Travel by Department:
#   department    business_travel  count
# 0         HR         Non-Travel      6
# 1         HR  Travel_Frequently     11
# 2         HR      Travel_Rarely     46
# 3        R&D         Non-Travel     97
# 4        R&D  Travel_Frequently    182
# 5        R&D      Travel_Rarely    682
# 6      Sales         Non-Travel     47
# 7      Sales  Travel_Frequently     84
# 8      Sales      Travel_Rarely    315
# 📊 19. Married Employees by Department:
#   department  married_count
# 0        R&D            433
# 1      Sales            206
# 2         HR             34
# 📊 20. Education vs Job Role Satisfaction:
#            education                   job_role  avg_satisfaction
# 0    Doctoral Degree  Healthcare Representative          3.333333
# 1  Associates Degree                    Manager          3.315789
# 2    Master's Degree       Sales Representative          3.062500
# 3    Doctoral Degree      Laboratory Technician          3.000000
# 4        High School            Human Resources          3.000000
# 5        High School            Sales Executive          2.962963
# 6        High School      Laboratory Technician          2.914286
# 7        High School         Research Scientist          2.891892
# 8    Master's Degree  Healthcare Representative          2.886364
# 9    Master's Degree         Research Scientist          2.886076
# 📊 21. Most Common Job Roles in Each Department:
#    department                   job_role  role_count
# 0          HR            Human Resources          52
# 1          HR                    Manager          11
# 2         R&D         Research Scientist         292
# 3         R&D      Laboratory Technician         259
# 4         R&D     Manufacturing Director         145
# 5         R&D  Healthcare Representative         131
# 6         R&D          Research Director          80
# 7         R&D                    Manager          54
# 8       Sales            Sales Executive         326
# 9       Sales       Sales Representative          83
# 10      Sales                    Manager          37
# 📊 22. Satisfaction by Education and Travel:
#             education    business_travel  avg_satisfaction
# 0   Associates Degree  Travel_Frequently          3.108696
# 1         High School  Travel_Frequently          3.081081
# 2     Doctoral Degree         Non-Travel          3.000000
# 3     Doctoral Degree  Travel_Frequently          2.900000
# 4     Master's Degree         Non-Travel          2.866667
# 5     Master's Degree  Travel_Frequently          2.845070
# 6   Bachelor's Degree         Non-Travel          2.836735
# 7     Master's Degree      Travel_Rarely          2.758865
# 8         High School      Travel_Rarely          2.737288
# 9   Associates Degree      Travel_Rarely          2.705000
# 10  Associates Degree         Non-Travel          2.694444
# 11  Bachelor's Degree      Travel_Rarely          2.665854
# 12        High School         Non-Travel          2.600000
# 13    Doctoral Degree      Travel_Rarely          2.545455
# 14  Bachelor's Degree  Travel_Frequently          2.522124
